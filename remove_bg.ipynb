# %% [markdown]
# <a href="https://colab.research.google.com/github/JanithaB/AI_Tools/blob/main/remove_bg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Remove Image Background**

# %% [markdown]
# ## Import & Install Necessary Libraries

# %%
# %%capture
# !pip install rembg
# !pip install pillow
# !pip install ipywidgets

from google.colab import files
from IPython.display import display, HTML, clear_output
from PIL import Image
from rembg import remove
import matplotlib.pyplot as plt
import io
import os
import uuid

# %% [markdown]
# ## Upload your Image

# %%
print("Please upload an image file:")
uploaded = files.upload()

if uploaded:
    for filename in uploaded.keys():
        print(f'User uploaded file "{filename}" with length {len(uploaded[filename])} bytes.')

        image = Image.open(io.BytesIO(uploaded[filename]))

        plt.imshow(image)
        plt.axis('off')
        plt.show()
else:
    print("No file was uploaded.")
# Out:
# Please upload an image file:
#      <input type="file" id="files-1592aaf8-2add-42ed-85af-01858663ac01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1592aaf8-2add-42ed-85af-01858663ac01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# ## Remove the background

# %%
if image.mode != 'RGBA':
                image = image.convert('RGBA')

output = remove(image)

plt.imshow(output)
plt.axis('off')
plt.show()

temp_filename = f"{uuid.uuid4()}.png"
output.save(temp_filename)

# %%
# @title Download Background Removed Image
files.download(temp_filename)
